# %%
import pandas as pd

# Full file path
file_path = r"C:\Users\Pavithra\OneDrive\Documents\Data Analytics Project 3\data\Chronic_Kidney_Disease.csv"

# Load dataset
df = pd.read_csv(file_path)

print("Dataset Loaded Successfully!")

print("\nRows and Columns:")
print(df.shape)

print("\nFirst Five Rows:")
print(df.head())
# Out:
# Dataset Loaded Successfully!
#
# Rows and Columns:
# (1659, 54)
#
# First Five Rows:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0          1   71       0          0                    0               2
# 1          2   34       0          0                    1               3
# 2          3   80       1          1                    0               1
# 3          4   40       0          2                    0               1
# 4          5   43       0          1                    1               2
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...   Itching  \
# 0  31.069414        1            5.128112          1.676220  ...  7.556302
# 1  29.692119        1           18.609552          8.377574  ...  6.836766
# 2  37.394822        1           11.882429          9.607401  ...  2.144722
# 3  31.329680        0           16.020165          0.408871  ...  7.077188
# ...
